# %%
import pandas as pd

drug_df = pd.read_csv("CICD-for-Machine-Learning2/Data/drug200.csv")
drug_df = drug_df.sample(frac=1)
drug_df.head(3)
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 58    60   M  NORMAL      NORMAL   10.091  drugX
# 143   74   M    HIGH      NORMAL   15.436  DrugY
# 89    50   F  NORMAL      NORMAL   17.211  DrugY

# %%
from sklearn.model_selection import train_test_split

X = drug_df.drop("Drug", axis=1).values
y = drug_df.Drug.values

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=125
)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

cat_col = [1,2,3]
num_col = [0,4]

transform = ColumnTransformer(
    [
        ("encoder", OrdinalEncoder(), cat_col),
        ("num_imputer", SimpleImputer(strategy="median"), num_col),
        ("num_scaler", StandardScaler(), num_col),
    ]
)
pipe = Pipeline(
    steps=[
        ("preprocessing", transform),
        ("model", RandomForestClassifier(n_estimators=100, random_state=125)),
    ]
)
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('encoder', OrdinalEncoder(),
#                                                   [1, 2, 3]),
#                                                  ('num_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   [0, 4]),
#                                                  ('num_scaler',
#                                                   StandardScaler(), [0, 4])])),
#                 ('model', RandomForestClassifier(random_state=125))])

# %%
from sklearn.metrics import accuracy_score, f1_score

predictions = pipe.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
f1 = f1_score(y_test, predictions, average="macro")

print("Accuracy:", str(round(accuracy, 2) * 100) + "%", "F1:", round(f1, 2))
# Out:
# Accuracy: 97.0% F1: 0.96

# %%
with open("CICD-for-Machine-Learning2/Results/metrics.txt", "w") as outfile:
    outfile.write(f"\nAccuracy = {round(accuracy, 2)}, F1 Score = {round(f1, 2)}.")

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

cm = confusion_matrix(y_test, predictions, labels=pipe.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipe.classes_)
disp.plot()
plt.savefig("CICD-for-Machine-Learning2/Results/model_results.png", dpi=120)

# %%
pip install skops
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import skops.io as sio

sio.dump(pipe, "CICD-for-Machine-Learning2/Model/drug_pipeline.skops")

# %%
sio.load("CICD-for-Machine-Learning2/Model/drug_pipeline.skops", trusted=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sio.load("CICD-for-Machine-Learning2/Model/drug_pipeline.skops", trusted=True)
#
# File c:\Users\User\anaconda3\envs\mon_env\lib\site-packages\skops\io\_persist.py:139, in load(file, trusted)
#     117 """Load an object saved with the skops persistence format.
#     118
#     119 Skops aims at providing a secure persistence feature that does not rely on
#    (...)
#     136
#     137 """
#     138 if trusted is True:
# --> 139     raise TypeError(
#     140         "trusted must be a list of strings. Before version 0.10 trusted could "
#     141         "be a boolean, but this is no longer supported, due to a reported "
#     142         "CVE-2024-37065. You can pass the output of `get_untrusted_types` as "
#     143         "trusted to load the data. Be sure to review the output of the function "
# ...

# %%
import skops.io as sio

skops_path = "CICD-for-Machine-Learning2/Model/drug_pipeline.skops"

# 1) Récupérer les types non sûrs à partir du fichier
unknown_types = sio.get_untrusted_types(file=skops_path)
print("Types non sûrs détectés :")
print(unknown_types)

# 2) Charger le modèle en autorisant ces types
pipe = sio.load(skops_path, trusted=unknown_types)
print("✅ Modèle chargé avec succès :", type(pipe))
# Out:
# Types non sûrs détectés :
# ['numpy.dtype']
# ✅ Modèle chargé avec succès : <class 'sklearn.pipeline.Pipeline'>
